# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#add your keys here
# This is used for authentication
# IMPORTANT: Use environment variables for production!
# For development only - replace with your own credentials
client_credentials_manager = SpotifyClientCredentials(client_id="YOUR_CLIENT_ID_HERE", client_secret="YOUR_CLIENT_SECRET_HERE")

# %%
# This creates an object, so that we can extract and use data. This basically means authorisation
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/1E9aGDTKixdZARu1BIK9V5"

# %%
playlist_URI = playlist_link.split("/")[-1].split('?')[0]

# %%
playlist_URI
# Out:
# '1E9aGDTKixdZARu1BIK9V5'

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/1E9aGDTKixdZARu1BIK9V5/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2025-01-25T14:36:53Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31q7b3do5364xnj3obr2yxpbwvja'},
#     'href': 'https://api.spotify.com/v1/users/31q7b3do5364xnj3obr2yxpbwvja',
#     'id': '31q7b3do5364xnj3obr2yxpbwvja',
#     'type': 'user',
#     'uri': 'spotify:user:31q7b3do5364xnj3obr2yxpbwvja'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
# ...

# %%
# Here the data will be stored in the items

# %%
data['items']
# Out:
# [{'added_at': '2025-01-25T14:36:53Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31q7b3do5364xnj3obr2yxpbwvja'},
#    'href': 'https://api.spotify.com/v1/users/31q7b3do5364xnj3obr2yxpbwvja',
#    'id': '31q7b3do5364xnj3obr2yxpbwvja',
#    'type': 'user',
#    'uri': 'spotify:user:31q7b3do5364xnj3obr2yxpbwvja'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '2025-01-25T14:36:53Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31q7b3do5364xnj3obr2yxpbwvja'},
#   'href': 'https://api.spotify.com/v1/users/31q7b3do5364xnj3obr2yxpbwvja',
#   'id': '31q7b3do5364xnj3obr2yxpbwvja',
#   'type': 'user',
#   'uri': 'spotify:user:31q7b3do5364xnj3obr2yxpbwvja'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
# ...

# %%
data['items'][1]
# Out:
# {'added_at': '2025-01-25T14:36:53Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31q7b3do5364xnj3obr2yxpbwvja'},
#   'href': 'https://api.spotify.com/v1/users/31q7b3do5364xnj3obr2yxpbwvja',
#   'id': '31q7b3do5364xnj3obr2yxpbwvja',
#   'type': 'user',
#   'uri': 'spotify:user:31q7b3do5364xnj3obr2yxpbwvja'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
# ...

# %%
data['items'][0]['track']
# Out:
# {'preview_url': None,
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
# ...

# %%
data['items'][0]['track']['album']
# Out:
# {'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '0upenH0uUT36nBbVM5mQhW'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Jo Tum Mere Ho'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2024-08-02'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/0upenH0uUT36nBbVM5mQhW'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                        'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
#From the messy data in the top, we tried to make the best possible way to clean and get the required albums 
album_list
# Out:
# [{'album_id': '0upenH0uUT36nBbVM5mQhW',
#   'name': 'Jo Tum Mere Ho',
#   'release_date': '2024-08-02',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0upenH0uUT36nBbVM5mQhW'},
#  {'album_id': '1ICG76ZLCkL5CSDCq5QDzt',
#   'name': 'Manase',
#   'release_date': '2022-09-22',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1ICG76ZLCkL5CSDCq5QDzt'},
#  {'album_id': '5mZX4EMwEyohNmVfLTDtXn',
#   'name': 'Satranga (From "ANIMAL")',
#   'release_date': '2023-10-27',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5mZX4EMwEyohNmVfLTDtXn'},
#  {'album_id': '5t9GkWCQGb0ejyH3c8zF1P',
#   'name': 'ANIMAL (TELUGU)',
#   'release_date': '2023-11-24',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/5t9GkWCQGb0ejyH3c8zF1P'},
#  {'album_id': '5I3dEH9cXdYmo8MVIdOkxO',
#   'name': 'Nuvvostanante Nenoddantana',
#   'release_date': '2005-01-14',
#   'total_tracks': 7,
# ...

# %%
album_list[1]
# Out:
# {'album_id': '1ICG76ZLCkL5CSDCq5QDzt',
#  'name': 'Manase',
#  'release_date': '2022-09-22',
#  'total_tracks': 1,
#  'url': 'https://open.spotify.com/album/1ICG76ZLCkL5CSDCq5QDzt'}

# %%
album_list[2]
# Out:
# {'album_id': '5mZX4EMwEyohNmVfLTDtXn',
#  'name': 'Satranga (From "ANIMAL")',
#  'release_date': '2023-10-27',
#  'total_tracks': 1,
#  'url': 'https://open.spotify.com/album/5mZX4EMwEyohNmVfLTDtXn'}

# %%
album_list[0]
# Out:
# {'album_id': '0upenH0uUT36nBbVM5mQhW',
#  'name': 'Jo Tum Mere Ho',
#  'release_date': '2024-08-02',
#  'total_tracks': 1,
#  'url': 'https://open.spotify.com/album/0upenH0uUT36nBbVM5mQhW'}

# %%
album_list[3]
# Out:
# {'album_id': '5t9GkWCQGb0ejyH3c8zF1P',
#  'name': 'ANIMAL (TELUGU)',
#  'release_date': '2023-11-24',
#  'total_tracks': 6,
#  'url': 'https://open.spotify.com/album/5t9GkWCQGb0ejyH3c8zF1P'}

# %%
data['items']
# Out:
# [{'added_at': '2025-01-25T14:36:53Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31q7b3do5364xnj3obr2yxpbwvja'},
#    'href': 'https://api.spotify.com/v1/users/31q7b3do5364xnj3obr2yxpbwvja',
#    'id': '31q7b3do5364xnj3obr2yxpbwvja',
#    'type': 'user',
#    'uri': 'spotify:user:31q7b3do5364xnj3obr2yxpbwvja'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
# ...

# %%
data['items'][0]['track']
# Out:
# {'preview_url': None,
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
# ...

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gdMJYnopf2nEUcanAwstx'},
#   'href': 'https://api.spotify.com/v1/artists/4gdMJYnopf2nEUcanAwstx',
#   'id': '4gdMJYnopf2nEUcanAwstx',
#   'name': 'Anuv Jain',
#   'type': 'artist',
#   'uri': 'spotify:artist:4gdMJYnopf2nEUcanAwstx'}]

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gdMJYnopf2nEUcanAwstx'},
#   'href': 'https://api.spotify.com/v1/artists/4gdMJYnopf2nEUcanAwstx',
#   'id': '4gdMJYnopf2nEUcanAwstx',
#   'name': 'Anuv Jain',
#   'type': 'artist',
#   'uri': 'spotify:artist:4gdMJYnopf2nEUcanAwstx'}]

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '4gdMJYnopf2nEUcanAwstx',
#   'artist_name': 'Anuv Jain',
#   'external_url': 'https://api.spotify.com/v1/artists/4gdMJYnopf2nEUcanAwstx'},
#  {'artist_id': '6ivte6aFersdzMprXpVDiO',
#   'artist_name': 'Dhruv Vikram',
#   'external_url': 'https://api.spotify.com/v1/artists/6ivte6aFersdzMprXpVDiO'},
#  {'artist_id': '3YJUwreoTZwxYUi472ECtS',
#   'artist_name': 'Ujwal Gupta',
#   'external_url': 'https://api.spotify.com/v1/artists/3YJUwreoTZwxYUi472ECtS'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '5o36rLQd78Zh8CaT8rn59d',
#   'artist_name': 'Shreyas Puranik',
#   'external_url': 'https://api.spotify.com/v1/artists/5o36rLQd78Zh8CaT8rn59d'},
#  {'artist_id': '6k6TIai4KyKG1DeIMftSmJ',
#   'artist_name': 'Siddharth - Garima',
#   'external_url': 'https://api.spotify.com/v1/artists/6k6TIai4KyKG1DeIMftSmJ'},
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                        name release_date  \
# 0  0upenH0uUT36nBbVM5mQhW              Jo Tum Mere Ho   2024-08-02
# 1  1ICG76ZLCkL5CSDCq5QDzt                      Manase   2022-09-22
# 2  5mZX4EMwEyohNmVfLTDtXn    Satranga (From "ANIMAL")   2023-10-27
# 3  5t9GkWCQGb0ejyH3c8zF1P             ANIMAL (TELUGU)   2023-11-24
# 4  5I3dEH9cXdYmo8MVIdOkxO  Nuvvostanante Nenoddantana   2005-01-14
#
#    total_tracks                                                url
# 0             1  https://open.spotify.com/album/0upenH0uUT36nBb...
# 1             1  https://open.spotify.com/album/1ICG76ZLCkL5CSD...
# 2             1  https://open.spotify.com/album/5mZX4EMwEyohNmV...
# 3             6  https://open.spotify.com/album/5t9GkWCQGb0ejyH...
# 4             7  https://open.spotify.com/album/5I3dEH9cXdYmo8M...

# %%
album_df.tail()
# Out:
#                  album_id                        name release_date  \
# 0  0upenH0uUT36nBbVM5mQhW              Jo Tum Mere Ho   2024-08-02
# 1  1ICG76ZLCkL5CSDCq5QDzt                      Manase   2022-09-22
# 2  5mZX4EMwEyohNmVfLTDtXn    Satranga (From "ANIMAL")   2023-10-27
# 3  5t9GkWCQGb0ejyH3c8zF1P             ANIMAL (TELUGU)   2023-11-24
# 4  5I3dEH9cXdYmo8MVIdOkxO  Nuvvostanante Nenoddantana   2005-01-14
#
#    total_tracks                                                url
# 0             1  https://open.spotify.com/album/0upenH0uUT36nBb...
# 1             1  https://open.spotify.com/album/1ICG76ZLCkL5CSD...
# 2             1  https://open.spotify.com/album/5mZX4EMwEyohNmV...
# 3             6  https://open.spotify.com/album/5t9GkWCQGb0ejyH...
# 4             7  https://open.spotify.com/album/5I3dEH9cXdYmo8M...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      5 non-null      object
#  1   name          5 non-null      object
#  2   release_date  5 non-null      datetime64[ns]
#  3   total_tracks  5 non-null      int64
#  4   url           5 non-null      object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 332.0+ bytes

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.info
# Out:
# <bound method DataFrame.info of                  album_id                        name release_date  \
# 0  0upenH0uUT36nBbVM5mQhW              Jo Tum Mere Ho   2024-08-02
# 1  1ICG76ZLCkL5CSDCq5QDzt                      Manase   2022-09-22
# 2  5mZX4EMwEyohNmVfLTDtXn    Satranga (From "ANIMAL")   2023-10-27
# 3  5t9GkWCQGb0ejyH3c8zF1P             ANIMAL (TELUGU)   2023-11-24
# 4  5I3dEH9cXdYmo8MVIdOkxO  Nuvvostanante Nenoddantana   2005-01-14
#
#    total_tracks                                                url
# 0             1  https://open.spotify.com/album/0upenH0uUT36nBb...
# 1             1  https://open.spotify.com/album/1ICG76ZLCkL5CSD...
# 2             1  https://open.spotify.com/album/5mZX4EMwEyohNmV...
# 3             6  https://open.spotify.com/album/5t9GkWCQGb0ejyH...
# 4             7  https://open.spotify.com/album/5I3dEH9cXdYmo8M...  >

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
album_df
# Out:
#                  album_id                        name release_date  \
# 0  0upenH0uUT36nBbVM5mQhW              Jo Tum Mere Ho   2024-08-02
# 1  1ICG76ZLCkL5CSDCq5QDzt                      Manase   2022-09-22
# 2  5mZX4EMwEyohNmVfLTDtXn    Satranga (From "ANIMAL")   2023-10-27
# 3  5t9GkWCQGb0ejyH3c8zF1P             ANIMAL (TELUGU)   2023-11-24
# 4  5I3dEH9cXdYmo8MVIdOkxO  Nuvvostanante Nenoddantana   2005-01-14
#
#    total_tracks                                                url
# 0             1  https://open.spotify.com/album/0upenH0uUT36nBb...
# 1             1  https://open.spotify.com/album/1ICG76ZLCkL5CSD...
# 2             1  https://open.spotify.com/album/5mZX4EMwEyohNmV...
# 3             6  https://open.spotify.com/album/5t9GkWCQGb0ejyH...
# 4             7  https://open.spotify.com/album/5I3dEH9cXdYmo8M...

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
#Song Dataframe
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id                 song_name  duration_ms  \
# 0  0eCajpR75pDW0r64U6hP2x            Jo Tum Mere Ho       251813
# 1  3XOj34b2q9npPGV75Kqsxc                    Manase       260216
# 2  3yHyiUDJdz02FZ6jfUbsmY  Satranga (From "ANIMAL")       271169
# 3  0ljjmkJocnhXzP62JYNW8p                 Evarevaro       250329
# 4  1ifMH14KizpUxIdRVyPsSZ               Niluvaddham       357336
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/0eCajpR75pDW0r6...          82
# 1  https://open.spotify.com/track/3XOj34b2q9npPGV...          31
# 2  https://open.spotify.com/track/3yHyiUDJdz02FZ6...          76
# 3  https://open.spotify.com/track/0ljjmkJocnhXzP6...          66
# 4  https://open.spotify.com/track/1ifMH14KizpUxId...          63
#
#              song_added                album_id               artist_id
# 0  2025-01-25T14:36:53Z  0upenH0uUT36nBbVM5mQhW  4gdMJYnopf2nEUcanAwstx
# ...

# %%
artist_df.head()
# Out:
#                 artist_id      artist_name  \
# 0  4gdMJYnopf2nEUcanAwstx        Anuv Jain
# 1  6ivte6aFersdzMprXpVDiO     Dhruv Vikram
# 2  3YJUwreoTZwxYUi472ECtS      Ujwal Gupta
# 3  4YRxDV8wJFPHPTeXepOstw     Arijit Singh
# 4  5o36rLQd78Zh8CaT8rn59d  Shreyas Puranik
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/4gdMJYnopf2...
# 1  https://api.spotify.com/v1/artists/6ivte6aFers...
# 2  https://api.spotify.com/v1/artists/3YJUwreoTZw...
# 3  https://api.spotify.com/v1/artists/4YRxDV8wJFP...
# 4  https://api.spotify.com/v1/artists/5o36rLQd78Z...

# %%
album_df.head()
# Out:
#                  album_id                        name release_date  \
# 0  0upenH0uUT36nBbVM5mQhW              Jo Tum Mere Ho   2024-08-02
# 1  1ICG76ZLCkL5CSDCq5QDzt                      Manase   2022-09-22
# 2  5mZX4EMwEyohNmVfLTDtXn    Satranga (From "ANIMAL")   2023-10-27
# 3  5t9GkWCQGb0ejyH3c8zF1P             ANIMAL (TELUGU)   2023-11-24
# 4  5I3dEH9cXdYmo8MVIdOkxO  Nuvvostanante Nenoddantana   2005-01-14
#
#    total_tracks                                                url
# 0             1  https://open.spotify.com/album/0upenH0uUT36nBb...
# 1             1  https://open.spotify.com/album/1ICG76ZLCkL5CSD...
# 2             1  https://open.spotify.com/album/5mZX4EMwEyohNmV...
# 3             6  https://open.spotify.com/album/5t9GkWCQGb0ejyH...
# 4             7  https://open.spotify.com/album/5I3dEH9cXdYmo8M...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
song_df['song_added'] =  pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      5 non-null      object
#  1   song_name    5 non-null      object
#  2   duration_ms  5 non-null      int64
#  3   url          5 non-null      object
#  4   popularity   5 non-null      int64
#  5   song_added   5 non-null      datetime64[ns, UTC]
#  6   album_id     5 non-null      object
#  7   artist_id    5 non-null      object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 452.0+ bytes
